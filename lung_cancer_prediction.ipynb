# %% [markdown]
# # Simple Logisitic Regression for prediciting lung cancer

# %% [markdown]
# ## Importing basic libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
raw_df = pd.read_csv("/lung_dataset.csv")

# %%
raw_df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
raw_df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
raw_df.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
sns.countplot(data=raw_df, x="SMOKING", hue="LUNG_CANCER", palette='rocket')
plt.title("Smoking vs Lung Cancer")
plt.xlabel("Smoking Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Histogram of age distribution

# %%
sns.histplot(data=raw_df, x="AGE", bins=20, color='crimson')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
# Calculate the correlation matrix
corr_matrix = raw_df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
one_hot = pd.get_dummies(raw_df['GENDER'])
data = raw_df.drop('GENDER', axis = 1)
data = data.join(one_hot)

# %% [markdown]
# ## Label encoding the data

# %%
from sklearn import preprocessing as prep
data['LUNG_CANCER'] = prep.LabelEncoder().fit_transform(data['LUNG_CANCER'])
data.head()
# Out:
#    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0   69        1               2        2              1                1
# 1   74        2               1        1              1                2
# 2   59        1               1        1              2                1
# 3   63        2               2        2              1                1
# 4   63        1               2        1              1                1
#
#    FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0         2         1         2                  2         2
# 1         2         2         1                  1         1
# 2         2         1         2                  1         2
# 3         1         1         1                  2         1
# 4         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER  F  M
# 0                    2                      2           2            1  0  1
# ...

# %% [markdown]
# data.columns

# %% [markdown]
# ## Features and y

# %%
features = ['AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY', 'PEER_PRESSURE',
       'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
       'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
       'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'F', 'M']
x = data[features]
y = data['LUNG_CANCER']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x,y)

# %%
split_info = {'total_entries': len(data.index), 'train_count': len(train_x.index), 'test_count' : len(test_x.index)}
split_info
# Out:
# {'total_entries': 309, 'train_count': 231, 'test_count': 78}

# %% [markdown]
# ## Importing logitistic regression model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model2 = LogisticRegression()
scaler = prep.StandardScaler().fit(train_x)
scaler.mean_
scaler.scale_
x_scaled = scaler.transform(train_x)
model2.fit(x_scaled, train_y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Prediciton and accuracy

# %%
y_pred = model2.predict(test_x)
accuracy_score(test_y, y_pred)
# Out:
# 0.8589743589743589

# %% [markdown]
# ## ROC curve

# %%
from sklearn.metrics import roc_curve, auc
# Compute the ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(test_y, y_pred)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
